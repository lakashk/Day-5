# %%
import pandas as pd

# %%
house_pricing = pd.read_csv("AB_US_2020.csv")
house_pricing
# Out:
# /opt/python/envs/default/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>host_id</th>
#       <th>host_name</th>
#       <th>neighbourhood_group</th>
#       <th>neighbourhood</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>room_type</th>
#       <th>price</th>
#       <th>minimum_nights</th>
#       <th>number_of_reviews</th>
#       <th>last_review</th>
# ...

# %%
house_pricing.info
# Out:
# <bound method DataFrame.info of               id                                               name  \
# 0          38585    Charming Victorian home - twin beds + breakfast
# 1          80905                                   French Chic Loft
# 2         108061  Walk to stores/parks/downtown. Fenced yard/Pet...
# 3         155305                 Cottage! BonPaul + Sharky's Hostel
# 4         160594                                Historic Grove Park
# ...          ...                                                ...
# 226025  45506143                          DC Hidden In Plain "Site"
# 226026  45511428  DC 3 BR w/ screen porch 3 blck to metro w/ par...
# 226027  45514685  Charming Penthouse Apt w/ Rooftop Terrace in L...
# 226028  45516412                Adams Morgan/Nat'l Zoo 1 BR Apt #32
# 226029  45517735    Beautiful large one-bedroom w/ washer and dryer
#
#           host_id  host_name neighbourhood_group  \
# 0          165529    Evelyne                 NaN
# ...

# %%
#remove nabourhood and city
house_pricing.drop(axis=1, columns=["neighbourhood","city"],inplace=True)
house_pricing
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>host_id</th>
#       <th>host_name</th>
#       <th>neighbourhood_group</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>room_type</th>
#       <th>price</th>
#       <th>minimum_nights</th>
#       <th>number_of_reviews</th>
#       <th>last_review</th>
#       <th>reviews_per_month</th>
#       <th>calculated_host_listings_count</th>
#       <th>availability_365</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>38585</td>
#       <td>Charming Victorian home - twin beds + breakfast</td>
#       <td>165529</td>
# ...

# %%
#to remove row number 2
house_pricing.drop(2,axis=0)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>host_id</th>
#       <th>host_name</th>
#       <th>neighbourhood_group</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>room_type</th>
#       <th>price</th>
#       <th>minimum_nights</th>
#       <th>number_of_reviews</th>
#       <th>last_review</th>
#       <th>reviews_per_month</th>
#       <th>calculated_host_listings_count</th>
#       <th>availability_365</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>38585</td>
#       <td>Charming Victorian home - twin beds + breakfast</td>
#       <td>165529</td>
# ...

# %%
iris = pd.read_csv("IRIS.csv")
iris
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
# ...

# %%
iris.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
iris.shape
# Out:
# (150, 5)

# %%
my_df = pd.DataFrame([[10,20,30,40,"Avatar"]])
my_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10</td>
#       <td>20</td>
#       <td>30</td>
#       <td>40</td>
#       <td>Avatar</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
my_df1 = pd.DataFrame([[10,20,30,40,"Avatar"]],columns=["sepal_length", "sepal_width","petal_length", "petal_width", "species"])
my_df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10</td>
#       <td>20</td>
#       <td>30</td>
#       <td>40</td>
#       <td>Avatar</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
iris.append(my_df1, ignore_index=True )
#op is not showing sorted output like 150 
#for that we used ignore indexing or by sorting the index
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
# ...

# %%
iris.tail()
#we have 5 row and 6 column 
#by defoult dataframe create 1 indexing colujmn
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>145</th>
#       <td>6.7</td>
#       <td>3.0</td>
#       <td>5.2</td>
#       <td>2.3</td>
#       <td>Iris-virginica</td>
#     </tr>
#     <tr>
#       <th>146</th>
#       <td>6.3</td>
#       <td>2.5</td>
#       <td>5.0</td>
#       <td>1.9</td>
#       <td>Iris-virginica</td>
#     </tr>
#     <tr>
#       <th>147</th>
#       <td>6.5</td>
#       <td>3.0</td>
#       <td>5.2</td>
#       <td>2.0</td>
# ...

# %%
#Append does not give inplace option 
#so that we have to reasssign to it
iris_df = iris.append(my_df1)

# %%
iris_df.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>146</th>
#       <td>6.3</td>
#       <td>2.5</td>
#       <td>5.0</td>
#       <td>1.9</td>
#       <td>Iris-virginica</td>
#     </tr>
#     <tr>
#       <th>147</th>
#       <td>6.5</td>
#       <td>3.0</td>
#       <td>5.2</td>
#       <td>2.0</td>
#       <td>Iris-virginica</td>
#     </tr>
#     <tr>
#       <th>148</th>
#       <td>6.2</td>
#       <td>3.4</td>
#       <td>5.4</td>
#       <td>2.3</td>
# ...

# %%
iris_df.reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>4.7</td>
# ...

# %%
iris_df["sepal_length"].sum()
# Out:
# 886.5

# %%
# iris["sepal_length"].sum()
iris.iloc[0:,].sum()
# Out:
# 'Iris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-setosaIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versicolorIris-versico
# ...

# %%
iris_sum = pd.DataFrame([[iris["sepal_length"].sum(),iris["sepal_width"].sum(),iris["petal_length"].sum(),iris["petal_width"].sum(),iris["Categorical_data"]], columns=["sepal_length","sepal_width","petal_length","petal_width","species"])
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
# SyntaxError: invalid character in identifier

# %%
iris=iris.append(iris_sum)
iris.reset_index(inplace=True,drop=True)
iris

# %%
sum_df = my_df = pd.DataFrame([[df.iloc[:,0].sum(), df.iloc[:,1].sum(), df.iloc[:,2].sum(), df.iloc[:,3].sum(), "SUM"]], columns=["sepal_length", "sepal_width","petal_length", "petal_width", "species"])frames = [df,sum_df]final_df = pd.concat(frames)final_df.reset_index(drop=True, inplace = True)

# %%
iris_df.sum()
# Out:
# <pre>sepal_length                                                886.5
# sepal_width                                                 478.1
# petal_length                                                593.8
# petal_width                                                 219.8
# species         Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object</pre>

# %%
iris_df.append(iris_df.sum, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
#     at line 8965 in append(self, other, ignore_index, verify_integrity, sort)
#     at line 311 in wrapper(*args, **kwargs)
#     at line 294 in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     at line 384 in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
# TypeError: cannot concatenate object of type '<class 'method'>'; only Series and DataFrame objs are valid

# %%
iris_df.nunique()
# Out:
# <pre>sepal_length    36
# sepal_width     24
# petal_length    44
# petal_width     23
# species          4
# dtype: int64</pre>

# %%
iris_df["species"].unique()
# Out:
# <pre>array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Avatar'],
#       dtype=object)</pre>

# %%
my_df1 = pd.DataFrame([[10,20,30,40,"Avatar"]],columns=["sepal_length", "sepal_width","petal_length", "petal_width", "species"])
my_df2 = pd.DataFrame([[10,20,30,40,"Avatar"]],columns=["sepal_length", "sepal_width","petal_length", "petal_width", "species"])

# %%
my_df1 + my_df2
#adding or concating the output addition
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20</td>
#       <td>40</td>
#       <td>60</td>
#       <td>80</td>
#       <td>AvatarAvatar</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
iris_df_1 = iris.drop(axis=1,columns=["species"])
iris_df_1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.6</td>
#       <td>3.1</td>
#       <td>1.5</td>
# ...

# %%
iris_df_2 = iris_df_1.copy()
iris_df_2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.6</td>
#       <td>3.1</td>
#       <td>1.5</td>
# ...

# %%
iris_df_3 = iris.iloc[0:,0:5] / iris_df_1.iloc[0:,0:]
iris_df_3
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
# ...

# %%
iris_df_3.join(iris_df["species"])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>Avatar</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>Iris-setosa</td>
# ...
